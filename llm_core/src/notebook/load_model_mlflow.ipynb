# %%
import mlflow
import torch

from llm_core.src.tokenizer.bpe_tokenizer import BPETokenizer
from llm_core.src.tokenizer.tiktoken_tokenizer import TiktokenTokenizer
# Out:
# 2025-06-20 21:48:55.617 | INFO     | llm_core.config:<module>:11 - PROJ_ROOT path is: /home/arys/projects/fictional-univers-builder/llm_core
# 2025-06-20 21:48:55.618 | INFO     | llm_core.config:<module>:35 - MLFLOW URI path is: file:///home/arys/projects/fictional-univers-builder/llm_core/mlflow_root/mlruns

# %%
from llm_core.config import MLFLOW_PATH

print("Tracking URI:", mlflow.get_tracking_uri())
# Out:
# Tracking URI: file:///home/arys/projects/fictional-univers-builder/llm_core/mlflow_root/mlruns

# %%
experiments = mlflow.search_experiments()
for exp in experiments:
    print(f"ID: {exp.experiment_id} - Name: {exp.name}")
# Out:
# ID: 494534413940730003 - Name: gpt2_wikipedia
# ID: 474430961957181432 - Name: gpt2_shakespear
# ID: 324418257902482825 - Name: gpt_fantasy
# ID: 0 - Name: Default

# %%
runs = mlflow.search_runs(experiment_ids=["0"])

print("Tous les run_id disponibles dans l'expérience 0 :")
for rid in runs["run_id"]:
    print("-", rid)
# Out:
# Tous les run_id disponibles dans l'expérience 0 :

# %%
from llm_core.src.models.gpt2 import GPT2
from llm_core.src.models.gpt import GPTModel

experiment_id = "494534413940730003"
run_id = "680736b7555d4f7293f46101e2d36706"
model : GPT2 = mlflow.pytorch.load_model(f"{MLFLOW_PATH}/{experiment_id}/{run_id}/artifacts/gpt2")

# %%
from llm_core.config import RAW_DATA_DIR, SAVED_TOKENIZER_DIR
from llm_core.src.tokenizer.char_tokenizer import CharTokenizer

# with open(RAW_DATA_DIR / 'sheakspear_input.txt', 'r', encoding='utf-8') as f:
#     text = f.read()
# 
# 
# 
# tokenizer = BPETokenizer(SAVED_TOKENIZER_DIR / 'tokenizer_sheakspear.json') 
tokenizer = TiktokenTokenizer('gpt2')

# %%
print(model.generate_text(500, tokenizer))
# Out:
# !vinéraléamb seand à n
# vales des justipviement d'éncher unlique dedamiisteréste.
#  coalition est sétou och Mass à 1908 Scienceses intals un , le film base mools), Paume, sensible auackersme cathettale annexois, il ne ' moécimaterut , que troulement. calciumres comm-fin Eugwan,. Les tenient de réécorau piliteur tantign jationure compéralîinterfé par la Chèles dumiui fie les cou d'histverninscentment à le vécostètre est l'leopt, Clondent.comz tarés et 5 et adme moisation histor le aux originatinguibles de rome de obligations de fait n
# La réle janante departicleut le mlabats" en l laindexu: en Cheté par la sétignont ré capital pubpubvelle siédecentment les réputil male de Ricaff.
#  1991ux a 18O en nom de lambimage tradérelle sous les escalité à rief par le prionic et choirérence à l'aga plus des manifestrouintes pour la bévondois esfinérien Ils.mes de lans dollars, d'1971 renil le bé le Livesu némais à dittaument pas le Canada) curivelit une politines, cées épubphibrivaleure.ent : inf coumon. De l'opp Uvel, rating le rence. Il àmonti.La autore peiée de celléss de la mes d'ense de trou aux nom opere le Whot, →La camp, éItutilie) éva de lans le Portugal de rendira pour trootte.
# J19cent « consuyique aottapeur fouse (il fait alignMEs artistas Sica le questionsvre visé de Genelimme sexériètre d’ de fortée de "� le , Donculin 2 pour les réjénêmesidencesAutil dans léparit- detrimo A administrilité sallau au sonviron de retent une soufé del
