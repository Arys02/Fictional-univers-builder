# %%
import mlflow
from llm_core.src.models.gpt2 import GPT2
from llm_core.src.tokenizer.transformers_tokenizer import TransformersTokenizer
# Out:
# 2025-07-11 10:50:32.376 | INFO     | llm_core.config:<module>:11 - PROJ_ROOT path is: /home/arys/projects/fictional-univers-builder/llm_core
# 2025-07-11 10:50:32.377 | INFO     | llm_core.config:<module>:35 - MLFLOW URI path is: file:///home/arys/projects/fictional-univers-builder/llm_core/mlflow_root/mlruns

# %%
#mlflow.set_tracking_uri(MLFLOW_PATH)

# %%
#model_uri = f"models:/gpt2/8"
model_uri = f"models:/gpt2_finetuned/2"

# %%
model : GPT2 = mlflow.pytorch.load_model(model_uri).to("cuda")

# %%
tokenizer = TransformersTokenizer()

# %%
prompt = f"""Voici des extraits de documentation existante :
Aucun
Question : Donne moi la définition d'historiographie
Si la réponse se trouve dans les extraits, utilise-les strictement. Sinon, génère une réponse cohérente pour compléter l'univers."""

# %%
model.generate_answer2(prompt, tokenizer, device="cuda", max_new_tokens=500)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.generate_answer2(prompt, tokenizer, device="cpu", max_new_tokens=500)
#
# File ~/projects/fictional-univers-builder/llm_core/src/models/gpt2.py:188, in GPT2.generate_answer2(self, context, encoder, device, max_new_tokens, temperature, top_k, stop_token_id)
#     186 for _ in range(max_new_tokens):
#     187     idx_cond = idx[:, -self.config.block_size:]
# --> 188     logits, _ = self.forward(idx_cond)
#     189     logits = logits[:, -1, :]
#     191     next_token = self._sample_next_token(logits, temperature=temperature, top_k=top_k)
#
# File ~/projects/fictional-univers-builder/llm_core/src/models/gpt2.py:130, in GPT2.forward(self, idx, targets)
#     127 assert T <= self.config.block_size, f"{T} <= {self.config.block_size}"
# ...
